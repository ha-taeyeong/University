# %% [markdown]
# # Week 9 Lab Exercise
# Note: Make sure you copied ALL files for this week into JupyterLite.

# %%
import networkx as nx
import matplotlib.pyplot as plt
import generalFunctions2 as gf

# %% [markdown]
# # Read  and show the example graph

# %%
G, layout = gf.read_graph_or_layout("island_hopping.layout", from_file=True, is_directed=False)
nx.draw(G, pos=layout, with_labels=True, node_color='lightblue', node_size=400, font_size=10, arrows=False)
plt.title("Example graph 'Island Hopping'")
plt.show()

# %% [markdown]
# # Now it is YOUR turn. Read this week's exercises and write code to solve them...
