# %% [markdown]
# # Week 13 Lab Exercise
# Note: Make sure you copied ALL files for this week into JupyterLite.

# %%
import networkx as nx
import matplotlib.pyplot as plt
import generalFunctions2 as gf
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# # Read  and show the example graph(s)

# %%
G, layout = gf.read_graph_or_layout("clausthal.layout", from_file=True, is_directed=False)
nx.draw(G, pos=layout, with_labels=True, node_color='lightblue', node_size=400, font_size=10, arrows=False)
plt.title("Example graph 'Clausthal'")
plt.show()
